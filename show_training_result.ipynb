# %%
import pickle
from plotting import show_train_per_time

# %%
with open('saved_model/random_data/train_history/full_models_acc_histroy.sav', 'rb') as file:
    history = pickle.load(file)
with open('saved_model/random_data/train_history/full_models_time_history.sav', 'rb') as file:
    time_callback = pickle.load(file)
# Out:
# Using TensorFlow backend.

# %%
show_train_per_time(history, time_callback)

# %%
time_callback.best_score
# Out:
# 0.18424978697289796

# %%
with open('saved_model/random_data/train_history/both_reduced_model_acc_histroy.sav', 'rb') as file:
    history = pickle.load(file)
with open('saved_model/random_data/train_history/both_reduced_model_time_history.sav', 'rb') as file:
    time_callback = pickle.load(file)

# %%
show_train_per_time(history, time_callback)

# %%
time_callback.best_score
# Out:
# 0.17051282048734845

# %%
with open('saved_model/clusterd_data/train_history/both_reduced_model_acc_histroy.sav', 'rb') as file:
    history = pickle.load(file)
with open('saved_model/clusterd_data/train_history/both_reduced_model_time_history.sav', 'rb') as file:
    time_callback = pickle.load(file)

# %%
show_train_per_time(history, time_callback)

# %%
time_callback.best_score
# Out:
# 0.18829923268575904
